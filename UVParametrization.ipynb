# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import random
import visvis as vv
import scipy
import math 
import skimage
import os 
#import sklearn
from skimage import measure
from numpy import sin, cos, sinh, cosh,arcsin,arccos, pi, exp, abs, max,min, sinh, cosh
from visvis import Point, Pointset
from scipy.spatial import Voronoi, voronoi_plot_2d, distance
from mpl_toolkits.mplot3d import axes3d
from matplotlib.animation import FuncAnimation


div_num = 30 
width = 0.5
R = 1
t = np.linspace(0,2*pi,div_num)
s = np.linspace(-width,width,div_num)

T,S = np.meshgrid(t,s)

x1 = (R+S*cos(0.5*T))*cos(T) 
y1 = (R+S*cos(0.5*T))*sin(T) 
z1 = R+S*sin(0.5*T)


fig = plt.figure(figsize=(5, 5))
ax = fig.add_subplot(111, projection='3d')

#ax.view_init(30, 4*i)
ax.plot_surface(x1, y1, z1)
''' 
def animate(i):
    plt.cla()
    ax.view_init(30, 4*i)
    ax.plot_surface(x1, y1, z1)
    
anim = FuncAnimation(fig, animate, interval=100)
'''

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()

#anim.save('Mobius.mp4')
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
# Klein bottle

div_num = 30  
r = 5
U = np.linspace(0,pi,div_num)
V = np.linspace(0,2*pi,div_num)

u,v = np.meshgrid(U,V)


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x2 = -2/15*cos(u)*(3*cos(v)-30*sin(u) +90*cos(u)**4*sin(u)-60*cos(u)**6*sin(u)+5*cos(u)*cos(v)*sin(u))
y2 = -1/15*sin(u)*(3*cos(v)-3*cos(u)**2*cos(v)-48*cos(u)**4*cos(v)+48*cos(u)**6*cos(v) - 60*sin(u)+5*cos(u)*cos(v)*sin(u)-5*cos(u)**3*cos(v)*sin(u)- 80*cos(u)**5*cos(v)*sin(u)+80*cos(u)**7*cos(v)*sin(u))
z2 = 2/15*(3+5*cos(u)*sin(u))*sin(v)

# if you want to create a 

#ax.scatter(x1,y1,z1)

ax.plot_surface(x2, y2, z2)
     
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x_evol = [] 
y_evol = []
z_evol = [] 


steps = 70
for i in range(steps):
    x_evol.append(x1 + i/steps*(x2 - x1))
    y_evol.append(y1 + i/steps*(y2 - y1))
    z_evol.append(z1 + i/steps*(z2 - z1))


x_evol = np.array(x_evol); y_evol = np.array(y_evol); z_evol = np.array(z_evol);  

fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')

def animate(i):
    plt.cla()
    ax.view_init(30, 4*i)
    ax.plot_surface(x_evol[i], y_evol[i], z_evol[i])
    
anim = FuncAnimation(fig, animate, interval=100)


ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()

anim.save('MobiustoKlein.mp4')
# Out:
# <div id='cf6ae6ff-9647-4dd7-8f70-b8069f3070be'></div>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-a9672cc272ed> in <module>
#      30 plt.show()
#      31
# ---> 32 anim.save('MobiustoKlein.mp4')
#
# ~\Anaconda3\envs\ML3DCAD\lib\site-packages\matplotlib\animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1146                     for anim, d in zip(all_anim, data):
#    1147                         # TODO: See if turning off blit is really necessary
# -> 1148                         anim._draw_next_frame(d, blit=False)
#    1149                         if progress_callback is not None:
#    1150                             progress_callback(frame_number, total_frames)
#
# ...
