# %%
# Creation of mobius
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import random
import visvis as vv
import scipy
import math 
import skimage
import os 
#import sklearn
from skimage import measure
from numpy import sin, cos, sinh, cosh,arcsin,arccos, pi, exp, abs, max,min, sinh, cosh
from visvis import Point, Pointset
from scipy.spatial import Voronoi, voronoi_plot_2d, distance
from mpl_toolkits.mplot3d import axes3d
from matplotlib.animation import FuncAnimation
from scipy.spatial import distance


n=5
bot = 0 
top = 6 

x = np.linspace(bot,top,n)
y = np.linspace(bot,top,n)

X, Y =  np.meshgrid(x, y)

# array to measure 
arr1 = ((X-3)**2 + (Y-3)**2)
arr1 = (max(arr1)-arr1)/(max(arr1)-min(arr1))
array1 = np.reshape(np.stack((X,Y)),(2, n**2)).T
arr2 = np.around(np.reshape(arr1,(n**2,)), decimals=2)  


fig = plt.figure(figsize=(4, 4))
#for i in range(array1.shape[0]): 
plt.scatter(array1[:,0], array1[:,1])
for i in range(array1.shape[0]): 
    plt.annotate(arr2[i], xy = array1[i,:])

plt.contour(X, Y, arr1, [0.8])

# For the contour

plt.axis('off')
plt.savefig('ptvalues2.png')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="400">
