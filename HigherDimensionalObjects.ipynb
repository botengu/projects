# %%
# Non orientable manifold 

import numpy as np
import random
import visvis as vv
import scipy
import math 
import skimage

# %matplotlib notebook

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d    

from math import factorial as fac
from skimage import measure
from numpy import sin, cos, sinh, cosh,arcsin,arccos, pi, exp,abs
from visvis import Point, Pointset
from scipy.spatial import Voronoi, voronoi_plot_2d, distance

# %%
# Set up mesh
# Create TPMS function 
def KleinBottle(u,v): 
    return  


n = 50 

u = np.linspace(0,pi,n)
v = np.linspace(0,2*pi,n)

x = -2/15*cos(u)*(3*cos(v)-30*sin(u)+90*(cos(u))**4*u*sin(u)-60*(cos(u))**6*u*sin(u)+5*cos(u)*cos(u)*cos(v)*sin(u)) 

y = -1/15*sin(u)*(3*cos(v)-3*cos(u)**2*u*cos(v) - 48*cos(u)**4*u*cos(v)-60*sin(u)+5*cos(u)*cos(v)*sin(u)-80*cos(u)**5*u*cos(v)*sin(u) +80*cos(u)**7*u*cos(v)*sin(u))

z = 2/15*(3+5*cos(u)*sin(u))*sin(v)



# Display the mesh
fig = plt.figure()
ax = fig.gca(projection = '3d')
ax.set_xlim3d(-2, 2)
ax.set_ylim3d(-2, 2)
ax.set_zlim3d(-2, 2)
ax.plot_trisurf(x, y, z)



'''
# Extract a 2D surface mesh from a 3D volume (F=0)
mesh = vv.isosurface(three,0)
m = vv.mesh(mesh)

#vv.meshWrite(os.path.expanduser('~/Desktop/CAGD/stlFiles/alone-sphere.stl'), m)
app = vv.use()
app.Run()

 print(z.shape)

'''
# Out:
# <img src="data:image/png;base64,..." width="640">
# "\n# Extract a 2D surface mesh from a 3D volume (F=0)\nmesh = vv.isosurface(three,0)\nm = vv.mesh(mesh)\n\n#vv.meshWrite(os.path.expanduser('~/Desktop/CAGD/stlFiles/alone-sphere.stl'), m)\napp = vv.use()\napp.Run()\n\n print(z.shape)\n\n"

# %%
n = 50 
l = 2
u = np.linspace(0,2*pi,n)
v = np.linspace(-1,1,n)

x = (1+v/2*cos(u/2))*cos(u)
y = (1+v/2*cos(u/2))*sin(u)
z = v/2*sin(u/2)



# Display the mesh
fig = plt.figure()
ax = fig.gca(projection = '3d')
ax.set_xlim3d(-l, l)
ax.set_ylim3d(-l, l)
ax.set_zlim3d(-l, l)
ax.plot_trisurf(x, y, z)
# Out:
# <img src="data:image/png;base64,..." width="640">
