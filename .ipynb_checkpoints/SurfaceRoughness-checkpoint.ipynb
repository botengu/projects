# %%
# Imports 
import numpy as np
import random
import math 
import matplotlib.pyplot as plt
from math import factorial as fac
from numpy import sin, cos, sinh, cosh,arcsin,arccos, pi, exp,abs
# %matplotlib notebook

n = 50
# number of places to change in array
num = int(n/2) 
array2 = np.reshape(np.arange(n),(n,1))

a3= np.zeros((n,1))
newArray = np.random.randint(0, n-1, size=(num, 1))
a3[newArray,:] = np.random.randint(-10, 10, size=(num, 1,1))
a3 = np.reshape(a3,(a3.shape[0],1))
array2 = np.hstack((array2,a3))


endpts = np.array([array2[0], array2[-1]])

plt.plot(array2[:,0],array2[:,1])
plt.plot(endpts[:,0],endpts[:,-1],c='r')
#plt.savefig('SR2.png')
plt.show()
'''
'''
# Out:
# <img src="data:image/png;base64,..." width="640">
# '\n'
