# %%
# Imports 
import numpy as np
import os
import random
import visvis as vv
import scipy
import math 
import skimage
import csv
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from skimage import measure
from numpy import sin, cos, sinh, cosh,arcsin,arccos, pi, exp,abs
from visvis import Point, Pointset
from scipy.spatial import Voronoi, voronoi_plot_2d, distance 
# %matplotlib notebook
''' 
def create_line(pt1,pt2): 
    l = Pointset(3)
    l.append(pt1);l.append(pt2); 
    vv.Line(axes,l)

def sol_line(pt1,pt2,rad): 
    l = Pointset(3)
    l.append(pt1);l.append(pt2); 
    return vv.solidLine(l, radius = rad)
'''
   
vert = [0.0,0.0,0.0] 

G = (1 + 5 ** 0.5) / 2
N = 10
pts =[]
pp = Pointset(3)
rho = 12 

# Outside points
for n in range(0,N):
    Phi_n = arccos(1 - 2*n/N)
    Theta_n = 2*pi * n / G
    x_n = vert[0] + rho*sin(Phi_n)*cos(Theta_n) 
    y_n = vert[1] + rho*sin(Phi_n)*sin(Theta_n)
    z_n = vert[2] + rho*cos(Phi_n)
    pts.append([x_n,y_n,z_n])
    #pp.append(Point(x_n,y_n,z_n)) 

pts = np.array(pts)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter3D(pts[:,0], pts[:,1], pts[:,2], c='r')

#plt.savefig('Bzvolume4wire.png')
plt.show()


'''
# Inside points
Num_pts = 50
for i in range(Num_pts):
    Phi_n = random.uniform(0, 2*pi)
    Theta_n = random.uniform(0, pi)
    rho_n = random.uniform(0.1*rho, 0.9*rho)
    x_n = vert.x + rho_n*sin(Phi_n)*cos(Theta_n) 
    y_n = vert.y + rho_n*sin(Phi_n)*sin(Theta_n)
    z_n = vert.z + rho_n*cos(Phi_n)
    pts.append([x_n,y_n,z_n])
    pp.append(Point(x_n,y_n,z_n))
    


# voronoi in 3D  
vor = Voronoi(pts)
edges  = np.array(vor.ridge_points)

edges = edges[np.all(edges != -1, axis=1)]
c = [] 
for i in range(len(edges)):
    pt1= Point(pts[edges[i,0]])
    pt2 = Point(pts[edges[i,1]])
    n1 = '~/Desktop/CAGD/stlFiles/rod' 
    n2 = str(i)
    n3 = '.stl'
    vv.meshWrite(os.path.expanduser(n1+n2+n3), sol_line(pt1,pt2,0.01))


# Exporting the points 
with open('pts.csv', 'w', newline='') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=' ', quotechar='|', quoting=csv.QUOTE_MINIMAL)
    for item in pts:
        spamwriter.writerow(item)
        
# Exporting the lines 
with open('edges.csv', 'w', newline='') as csvfile:
    spamwriter = csv.writer(csvfile, delimiter=' ', quotechar='|', quoting=csv.QUOTE_MINIMAL)
    for item in edges:
        spamwriter.writerow(item)


app = vv.use()
app.Run()
'''
# Out:
# <img src="data:image/png;base64,..." width="640">
# ...

# %%
print(pts)
# Out:
# [[ 0.00000000e+00  0.00000000e+00  1.20000000e+01]
#  [-5.30905592e+00 -4.86353012e+00  9.60000000e+00]
#  [ 8.39286957e-01  9.56324199e+00  7.20000000e+00]
#  [ 6.69172113e+00 -8.72816523e+00  4.80000000e+00]
#  [-1.15778188e+01  2.04795312e+00  2.40000000e+00]
#  [ 1.01250635e+01  6.44073663e+00  7.34788079e-16]
#  [-3.05231079e+00 -1.13544440e+01 -2.40000000e+00]
#  [-5.06913919e+00  9.76031905e+00 -4.80000000e+00]
#  [ 9.01748444e+00 -3.29317086e+00 -7.20000000e+00]
#  [-6.65528800e+00 -2.74720614e+00 -9.60000000e+00]]
