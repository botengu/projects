# %%
import sys
import scipy
import csv
import numpy as np 
import matplotlib.pyplot as plt
import math    
import visvis as vv

from math import atan, factorial as fac
from skimage import measure
from numpy import sin, cos, sinh, cosh,arcsin,arccos, pi, exp,abs, sqrt
from visvis import Point, Pointset
from scipy.spatial import Voronoi, voronoi_plot_2d, distance
from matplotlib.collections import LineCollection

nelx = 150
nely = 50
thres = 0.3
min_ms = 1 


# Open the densities 
densities = []

with open('C:\\Users\\AdminSi\\Desktop\\Masters\\Matlab\\Physics11.csv') as csvfile:
    readCSV = csv.reader(csvfile)
    for row in readCSV:
        for i in row:
            densities.append(float(i))     

# Interpret the indexing 
# Only create boxes when the density is above the threshold  

pixels = np.reshape(densities, (nely, nelx))
pixelsbig = np.zeros((nely+20,nelx+10))

pixelsbig[10:-10,5:-5] = pixels
# Find contours at a constant value of 0.8
contours = measure.find_contours(pixelsbig, 0.5)

# Display the image and plot all contours found


for n, contour in enumerate(contours):
    ax.plot(contour[:, 1], contour[:, 0], linewidth=2)

pts_list= []     
for collection in contours:
    for item in collection:
        pts_list.append(item)
    
pts_list = np.array(pts_list)
print(pts_list)

vor = Voronoi(pts_list)
fig = voronoi_plot_2d(vor,show_vertices=False, line_width=2, line_alpha=0.6, point_size=5)
edges  = np.array(vor.ridge_vertices)
pts = vor.vertices 
edges = edges[np.all(edges != -1, axis=1)]

lc = LineCollection(pts[edges])
fig = plt.figure()
plt.gca().add_collection(lc)
plt.xlim(-10, nely+10)
plt.ylim(0, nelx)

'''    
fig, ax = plt.subplots()
ax.imshow(pixelsbig*0+1, cmap=plt.cm.gray)
ax.axis('image')
ax.set_xticks([])
ax.set_yticks([])
plt.show()
'''
# Out:
# [[ 59.49948738 154.        ]
#  [ 59.49998297 153.        ]
#  [ 59.4995806  152.        ]
#  ...
#  [ 47.          58.19042558]
#  [ 47.56860347  59.        ]
#  [ 47.          59.84393906]]
# "    \nfig, ax = plt.subplots()\nax.imshow(pixelsbig*0+1, cmap=plt.cm.gray)\nax.axis('image')\nax.set_xticks([])\nax.set_yticks([])\nplt.show()\n"
