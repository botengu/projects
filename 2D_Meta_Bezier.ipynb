# %%
import numpy as np
import visvis as vv
import math   
import skimage
import os
import random
import scipy
import skimage
import matplotlib.pyplot as plt



from math import factorial as fac
from skimage import measure
from numpy import sin, cos, sinh, cosh,arcsin,arccos, pi, exp,abs, min, max 
from visvis import Point, Pointset
from scipy.spatial import Voronoi, voronoi_plot_2d, distance
from numpy import inf

# %%
#axes = vv.gca()


# Construct some test data
x, y = np.ogrid[-np.pi:np.pi:100j, -np.pi:np.pi:100j]
r = np.sin(np.exp((np.sin(x)**3 + np.cos(y)**2)))

# Find contours at a constant value of 0.8
contours = measure.find_contours(r, 0.8)

# Display the image and plot all contours found
fig, ax = plt.subplots()
ax.imshow(r, cmap=plt.cm.gray)

for n, contour in enumerate(contours):
    ax.plot(contour[:, 1], contour[:, 0], linewidth=2)

ax.axis('image')
ax.set_xticks([])
ax.set_yticks([])
plt.show()
'''
app = vv.use()
app.Run()

'''
# Out:
# '\napp = vv.use()\napp.Run()\n\n'

# %%
print(r)
# Out:
# [[0.41078129 0.420706   0.44978612 ... 0.44978612 0.420706   0.41078129]
#  [0.41141341 0.42133245 0.45039549 ... 0.45039549 0.42133245 0.41141341]
#  [0.41579783 0.42567738 0.45462161 ... 0.45462161 0.42567738 0.41579783]
#  ...
#  [0.40574206 0.41571182 0.44492756 ... 0.44492756 0.41571182 0.40574206]
#  [0.41014881 0.4200792  0.44917639 ... 0.44917639 0.4200792  0.41014881]
#  [0.41078129 0.420706   0.44978612 ... 0.44978612 0.420706   0.41078129]]
